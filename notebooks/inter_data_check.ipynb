# %%
import pandas as pd

# %%
articles = pd.read_parquet("../data/02_intermediate/articles.parquet")
customers = pd.read_parquet("../data/02_intermediate/customers.parquet")
transactions_train = pd.read_parquet("../data/02_intermediate/transactions_train.parquet")

# %%
articles.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %%
customers.head()
# Out:
#             customer_id   FN  Active club_member_status  \
# 0   6883939031699146327  NaN     NaN             ACTIVE
# 1  11246327431398957306  NaN     NaN             ACTIVE
# 2  18439897732908966680  NaN     NaN             ACTIVE
# 3  18352672461570950206  NaN     NaN             ACTIVE
# 4  18162778555210377306  1.0     1.0             ACTIVE
#
#   fashion_news_frequency   age  \
# 0                   NONE  49.0
# 1                   NONE  25.0
# 2                   NONE  24.0
# 3                   NONE  54.0
# 4              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %%
transactions_train.head()
# Out:
#         t_dat           customer_id  article_id     price  sales_channel_id
# 0  2018-09-20  18439897732908966680   663713001  0.050831                 2
# 1  2018-09-20  18439897732908966680   541518023  0.030492                 2
# 2  2018-09-20  10112112306570742978   505221004  0.015237                 2
# 3  2018-09-20  10112112306570742978   685687003  0.016932                 2
# 4  2018-09-20  10112112306570742978   685687004  0.016932                 2

# %%
transactions_train.groupby(["customer_id"])["article_id"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12060\2899821417.py in <cell line: 1>()
# ----> 1 transactions_train.groupby(["customer_id"])["article_id"].unique()
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\groupby\groupby.py in wrapper(*args, **kwargs)
#     948                 return self.apply(curried)
#     949
# --> 950             return self._python_apply_general(curried, self._obj_with_exclusions)
#     951
#     952         wrapper.__name__ = name
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data, not_indexed_same)
#    1453             data after applying f
#    1454         """
# -> 1455         values, mutated = self.grouper.apply(f, data, self.axis)
#    1456
#    1457         if not_indexed_same is None:
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     759             # group might be modified
#     760             group_axes = group.axes
# --> 761             res = f(group)
#     762             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763                 mutated = True
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\groupby\groupby.py in curried(x)
#     937
#     938             def curried(x):
# --> 939                 return f(x, *args, **kwargs)
#     940
#     941             # preserve the name so we can detect it when calling plot methods,
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\series.py in unique(self)
#    2086         Categories (3, object): ['a' < 'b' < 'c']
#    2087         """
# -> 2088         return super().unique()
#    2089
#    2090     @overload
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\base.py in unique(self)
#     987                     result = np.asarray(result)
#     988         else:
# --> 989             result = unique1d(values)
#     990
#     991         return result
#
# D:\ProgramFiles\anaconda3\envs\kedro-env\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     438
#     439     table = htable(len(values))
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# KeyboardInterrupt:

# %%
len(transactions_train.t_dat.unique()) / 7
# Out:
# 104.85714285714286
